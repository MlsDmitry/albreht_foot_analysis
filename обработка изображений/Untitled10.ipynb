# %%
import torch.nn as nn
import torch
import numpy as np

# %%
# model = nn.MaxPool1d(2)
model = nn.AvgPool1d(2, ceil_mode=True)
model
# Out:
# AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))

# %%
inp = np.asarray([[1, 3, 4, 2, 3, 4, 5, 1, 0]], dtype=np.double)
print(inp)
inp = torch.from_numpy(inp)
inp.shape
# Out:
# [[1. 3. 4. 2. 3. 4. 5. 1. 0.]]
# torch.Size([1, 9])

# %%
model(inp)
# Out:
# tensor([[2.0000, 3.0000, 3.5000, 3.0000, 0.0000]], dtype=torch.float64)
